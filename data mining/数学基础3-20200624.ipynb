# %%
import pandas as pd 
import seaborn as sns 
import numpy as np

# %%
ar = np.random.randn(20, 4) 
print(type(ar))
print(ar)
# Out:
# <class 'numpy.ndarray'>
# [[ 0.45856238 -0.17698499  0.43492417  0.18553271]
#  [ 1.5190213   0.0627079  -0.02849662  0.34588554]
#  [ 1.54556706  0.8859713   0.3409181   0.67034953]
#  [ 0.23074096 -0.01714026  0.93539448 -1.37161025]
#  [-1.91660104 -1.36404751  0.26678663  0.14598771]
#  [ 0.42239664  0.77601492 -0.80010398  0.16887818]
#  [ 0.41528913  0.61434102 -1.63098332  0.18594243]
#  [-1.14472851  1.79547634  0.06774681  1.25016772]
#  [ 0.99920984  0.30842388  0.92391286  0.25695839]
#  [-0.12934182 -1.8291851  -0.88408067 -0.13661572]
#  [ 1.26242267 -0.1522933   1.65533231 -0.27386872]
#  [-0.7172427  -0.70831479 -0.23826671  0.20164936]
#  [ 0.6863581   1.45567995 -0.20844937  1.62732327]
#  [-1.75273947 -1.08360077  1.29708077  0.34019998]
#  [-0.77000148 -0.03276205  0.51666488  0.11848846]
#  [-0.97473699  0.46010996 -0.47508174 -1.21166032]
#  [ 0.73475494  0.54933352  2.06926634  0.89664026]
#  [-1.74510721  0.1400228   0.76180326  1.84377796]
#  [ 0.13916561  0.10656725  1.75928415  2.64145031]
#  [ 1.79269237  0.40275434  1.52050162 -0.31865964]]

# %%
df = pd.DataFrame(ar, columns=['a', 'b', 'c', 'd']) 
df['e'] = pd.Series([    'one', 'one', 'one', 'one', 'one', 'one', 'two', 'two', 'two', 'two',    'two', 'two', 'two', 'two', 'three', 'three', 'three', 'three', 'three',    'three' ]) 
df
# Out:
#            a         b         c         d      e
# 0   0.458562 -0.176985  0.434924  0.185533    one
# 1   1.519021  0.062708 -0.028497  0.345886    one
# 2   1.545567  0.885971  0.340918  0.670350    one
# 3   0.230741 -0.017140  0.935394 -1.371610    one
# 4  -1.916601 -1.364048  0.266787  0.145988    one
# 5   0.422397  0.776015 -0.800104  0.168878    one
# 6   0.415289  0.614341 -1.630983  0.185942    two
# 7  -1.144729  1.795476  0.067747  1.250168    two
# 8   0.999210  0.308424  0.923913  0.256958    two
# 9  -0.129342 -1.829185 -0.884081 -0.136616    two
# 10  1.262423 -0.152293  1.655332 -0.273869    two
# 11 -0.717243 -0.708315 -0.238267  0.201649    two
# 12  0.686358  1.455680 -0.208449  1.627323    two
# 13 -1.752739 -1.083601  1.297081  0.340200    two
# 14 -0.770001 -0.032762  0.516665  0.118488  three
# 15 -0.974737  0.460110 -0.475082 -1.211660  three
# 16  0.734755  0.549334  2.069266  0.896640  three
# 17 -1.745107  0.140023  0.761803  1.843778  three
# 18  0.139166  0.106567  1.759284  2.641450  three
# 19  1.792692  0.402754  1.520502 -0.318660  three

# %%
sns.scatterplot(df['a'], df['b'], hue=df['e'])
