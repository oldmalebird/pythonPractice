# %%
import numpy as np
import matplotlib.pyplot as plt
# 读取图像文件，参数指定图像文件的路径，返回图像的ndarray数组。
data = plt.imread("批注 2019-09-11 122850.jpg")
print(type(data))
# Out:
# <class 'numpy.ndarray'>

# %%
data2 = data[:, ::-1, :]

# %%
plt.imshow(data2)
