# %%
import pandas as pd
import numpy as np

# %%
docAddress = r"C:\Users\MaleBird\Desktop\【大数据文件1】huodianhour2019_v4.csv"

# %%
df = pd.read_csv(docAddress,engine='python')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1911687 entries, 0 to 1911686
# Data columns (total 15 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   pscode             int64
#  1   outputcode         int64
#  2   pollutant_code     int64
#  3   psname             object
#  4   outputname         object
#  5   PollutantName      object
#  6   data_time          object
#  7   RevisedStrength    float64
#  8   RevisedzsStrength  float64
#  9   RevisedFlow        float64
#  10  flow               float64
#  11  VALUES01           float64
#  12  VALUES03           float64
#  13  VALUES05           float64
#  14  StandardValue      int64
# dtypes: float64(7), int64(4), object(4)
# memory usage: 218.8+ MB

# %%
df.head()
# Out:
#          pscode  outputcode  pollutant_code        psname outputname  \
# 0  640000000005         201               3  华电宁夏灵武发电有限公司      脱硫出口1
# 1  640000000005         201               3  华电宁夏灵武发电有限公司      脱硫出口1
# 2  640000000005         201               3  华电宁夏灵武发电有限公司      脱硫出口1
# 3  640000000005         201               3  华电宁夏灵武发电有限公司      脱硫出口1
# 4  640000000005         201               3  华电宁夏灵武发电有限公司      脱硫出口1
#
#   PollutantName            data_time  RevisedStrength  RevisedzsStrength  \
# 0          氮氧化物  2019-07-11 05:00:00           41.041             38.722
# 1          氮氧化物  2019-07-11 06:00:00           44.454             42.167
# 2          氮氧化物  2019-07-11 07:00:00           47.266             45.024
# 3          氮氧化物  2019-07-11 08:00:00           40.486             39.561
# 4          氮氧化物  2019-07-11 09:00:00           33.393             35.648
#
#    RevisedFlow        flow  VALUES01  VALUES03  VALUES05  StandardValue
# ...

# %%
df.nunique()
# Out:
# pscode                   49
# outputcode               40
# pollutant_code            3
# psname                   49
# outputname               88
# PollutantName             3
# data_time              8760
# RevisedStrength      159345
# RevisedzsStrength    188052
# RevisedFlow          128966
# flow                 597860
# VALUES01              34134
# VALUES03              74230
# VALUES05              39109
# StandardValue             9
# dtype: int64

# %%
df.columns('pscode','OutputCode','PollutantCode','psname','PollutantName','MonitorTime','RevisedStrength','RzsStrength','RevisedFlow','cou','S01','S03','S05','StandardValue')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-2c69120f35ef> in <module>
# ----> 1 df.columns('pscode','OutputCode','PollutantCode','psname','PollutantName','MonitorTime','RevisedStrength','RzsStrength','RevisedFlow','cou','S01','S03','S05','StandardValue')
#
# TypeError: 'Index' object is not callable

# %%
list(df)
# Out:
# ['pscode',
#  'outputcode',
#  'pollutant_code',
#  'psname',
#  'outputname',
#  'PollutantName',
#  'data_time',
#  'RevisedStrength',
#  'RevisedzsStrength',
#  'RevisedFlow',
#  'flow',
#  'VALUES01',
#  'VALUES03',
#  'VALUES05',
#  'StandardValue']

# %%
df.rename(columns={'outputcode':'OutputCode'})
# Out:
#                pscode  OutputCode  pollutant_code        psname outputname  \
# 0        640000000005         201               3  华电宁夏灵武发电有限公司      脱硫出口1
# 1        640000000005         201               3  华电宁夏灵武发电有限公司      脱硫出口1
# 2        640000000005         201               3  华电宁夏灵武发电有限公司      脱硫出口1
# 3        640000000005         201               3  华电宁夏灵武发电有限公司      脱硫出口1
# 4        640000000005         201               3  华电宁夏灵武发电有限公司      脱硫出口1
# ...               ...         ...             ...           ...        ...
# 1911682  640000000005         201               3  华电宁夏灵武发电有限公司      脱硫出口1
# 1911683  640000000005         201               3  华电宁夏灵武发电有限公司      脱硫出口1
# 1911684  640000000005         201               3  华电宁夏灵武发电有限公司      脱硫出口1
# 1911685  640000000005         201               3  华电宁夏灵武发电有限公司      脱硫出口1
# 1911686  640000000005         201               3  华电宁夏灵武发电有限公司      脱硫出口1
#
#         PollutantName            data_time  RevisedStrength  \
# ...

# %%
df.rename(columns={'pollutant_code':'PollutantCode','outputname':'OutputName','data_time':'MonitorTime'})
# Out:
#                pscode  outputcode  PollutantCode        psname OutputName  \
# 0        640000000005         201              3  华电宁夏灵武发电有限公司      脱硫出口1
# 1        640000000005         201              3  华电宁夏灵武发电有限公司      脱硫出口1
# 2        640000000005         201              3  华电宁夏灵武发电有限公司      脱硫出口1
# 3        640000000005         201              3  华电宁夏灵武发电有限公司      脱硫出口1
# 4        640000000005         201              3  华电宁夏灵武发电有限公司      脱硫出口1
# ...               ...         ...            ...           ...        ...
# 1911682  640000000005         201              3  华电宁夏灵武发电有限公司      脱硫出口1
# 1911683  640000000005         201              3  华电宁夏灵武发电有限公司      脱硫出口1
# 1911684  640000000005         201              3  华电宁夏灵武发电有限公司      脱硫出口1
# 1911685  640000000005         201              3  华电宁夏灵武发电有限公司      脱硫出口1
# 1911686  640000000005         201              3  华电宁夏灵武发电有限公司      脱硫出口1
#
#         PollutantName          MonitorTime  RevisedStrength  \
# ...

# %%
df.rename(columns={'RevisedzsStrength':'RzsStrength','flow':'cou','VALUES01':'S01','VALUES02':'S02','VALUES03':'S03'})
# Out:
#                pscode  outputcode  pollutant_code        psname outputname  \
# 0        640000000005         201               3  华电宁夏灵武发电有限公司      脱硫出口1
# 1        640000000005         201               3  华电宁夏灵武发电有限公司      脱硫出口1
# 2        640000000005         201               3  华电宁夏灵武发电有限公司      脱硫出口1
# 3        640000000005         201               3  华电宁夏灵武发电有限公司      脱硫出口1
# 4        640000000005         201               3  华电宁夏灵武发电有限公司      脱硫出口1
# ...               ...         ...             ...           ...        ...
# 1911682  640000000005         201               3  华电宁夏灵武发电有限公司      脱硫出口1
# 1911683  640000000005         201               3  华电宁夏灵武发电有限公司      脱硫出口1
# 1911684  640000000005         201               3  华电宁夏灵武发电有限公司      脱硫出口1
# 1911685  640000000005         201               3  华电宁夏灵武发电有限公司      脱硫出口1
# 1911686  640000000005         201               3  华电宁夏灵武发电有限公司      脱硫出口1
#
# ...

# %%
df.rename(columns={'VALUES05':'S05'})
# Out:
#                pscode  outputcode  pollutant_code        psname outputname  \
# 0        640000000005         201               3  华电宁夏灵武发电有限公司      脱硫出口1
# 1        640000000005         201               3  华电宁夏灵武发电有限公司      脱硫出口1
# 2        640000000005         201               3  华电宁夏灵武发电有限公司      脱硫出口1
# 3        640000000005         201               3  华电宁夏灵武发电有限公司      脱硫出口1
# 4        640000000005         201               3  华电宁夏灵武发电有限公司      脱硫出口1
# ...               ...         ...             ...           ...        ...
# 1911682  640000000005         201               3  华电宁夏灵武发电有限公司      脱硫出口1
# 1911683  640000000005         201               3  华电宁夏灵武发电有限公司      脱硫出口1
# 1911684  640000000005         201               3  华电宁夏灵武发电有限公司      脱硫出口1
# 1911685  640000000005         201               3  华电宁夏灵武发电有限公司      脱硫出口1
# 1911686  640000000005         201               3  华电宁夏灵武发电有限公司      脱硫出口1
#
#         PollutantName            data_time  RevisedStrength  \
# ...

# %%
df.head()
# Out:
#          pscode  outputcode  pollutant_code        psname outputname  \
# 0  640000000005         201               3  华电宁夏灵武发电有限公司      脱硫出口1
# 1  640000000005         201               3  华电宁夏灵武发电有限公司      脱硫出口1
# 2  640000000005         201               3  华电宁夏灵武发电有限公司      脱硫出口1
# 3  640000000005         201               3  华电宁夏灵武发电有限公司      脱硫出口1
# 4  640000000005         201               3  华电宁夏灵武发电有限公司      脱硫出口1
#
#   PollutantName            data_time  RevisedStrength  RevisedzsStrength  \
# 0          氮氧化物  2019-07-11 05:00:00           41.041             38.722
# 1          氮氧化物  2019-07-11 06:00:00           44.454             42.167
# 2          氮氧化物  2019-07-11 07:00:00           47.266             45.024
# 3          氮氧化物  2019-07-11 08:00:00           40.486             39.561
# 4          氮氧化物  2019-07-11 09:00:00           33.393             35.648
#
#    RevisedFlow        flow  VALUES01  VALUES03  VALUES05  StandardValue
# ...

# %%
df2 = df.rename(columns={'outputcode':'OutputCode','pollutant_code':'PollutantCode','outputname':'OutputName','data_time':'MonitorTime','RevisedzsStrength':'RzsStrength','flow':'cou','VALUES01':'S01','VALUES03':'S03','VALUES05':'S05'})

# %%
df2.to_csv('huodianhour2019_v4-2.csv', index=False)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1911687 entries, 0 to 1911686
# Data columns (total 15 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   pscode           int64
#  1   OutputCode       int64
#  2   PollutantCode    int64
#  3   psname           object
#  4   OutputName       object
#  5   PollutantName    object
#  6   MonitorTime      object
#  7   RevisedStrength  float64
#  8   RzsStrength      float64
#  9   RevisedFlow      float64
#  10  cou              float64
#  11  S01              float64
#  12  S03              float64
#  13  S05              float64
#  14  StandardValue    int64
# dtypes: float64(7), int64(4), object(4)
# memory usage: 218.8+ MB

# %%
docAddress = r"C:\Users\MaleBird\Desktop\火电行业2019年数据\huodian2019_v4.csv"
df = pd.read_csv(docAddress,engine='python') 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78262 entries, 0 to 78261
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   pscode             78262 non-null  int64
#  1   outputcode         78262 non-null  int64
#  2   pollutant_code     78262 non-null  int64
#  3   psname             78262 non-null  object
#  4   outputname         78262 non-null  object
#  5   PollutantName      78262 non-null  object
#  6   data_time          78262 non-null  object
#  7   RevisedStrength    78262 non-null  float64
#  8   RevisedzsStrength  77423 non-null  float64
#  9   RevisedFlow        78262 non-null  float64
#  10  flow               78262 non-null  float64
#  11  VALUES01           78262 non-null  float64
#  12  VALUES03           78262 non-null  float64
#  13  VALUES05           74596 non-null  float64
#  14  StandardValue      78262 non-null  int64
# dtypes: float64(7), int64(4), object(4)
# ...

# %%
df.head()
# Out:
#          pscode  outputcode  pollutant_code            psname outputname  \
# 0  620000000094           2               3  大唐甘肃发电有限公司八零三热电厂   1号机组脱硫出口
# 1  620000000094           2               2  大唐甘肃发电有限公司八零三热电厂   1号机组脱硫出口
# 2  620000000094           2               1  大唐甘肃发电有限公司八零三热电厂   1号机组脱硫出口
# 3  620000000094           2               3  大唐甘肃发电有限公司八零三热电厂   1号机组脱硫出口
# 4  620000000094           2               2  大唐甘肃发电有限公司八零三热电厂   1号机组脱硫出口
#
#   PollutantName            data_time  RevisedStrength  RevisedzsStrength  \
# 0          氮氧化物  2019-09-06 00:00:00            5.598              7.556
# 1          二氧化硫  2019-09-06 00:00:00            0.000             -0.200
# 2            烟尘  2019-09-06 00:00:00            2.470             -8.750
# 3          氮氧化物  2019-09-11 00:00:00          116.123            357.576
# 4          二氧化硫  2019-09-11 00:00:00            0.000              0.000
#
#    RevisedFlow        flow  VALUES01  VALUES03  VALUES05  StandardValue
# ...

# %%
df.nunique()
# Out:
# pscode                  49
# outputcode              40
# pollutant_code           3
# psname                  49
# outputname              88
# PollutantName            3
# data_time              365
# RevisedStrength      34106
# RevisedzsStrength    39108
# RevisedFlow          57811
# flow                 24954
# VALUES01              9272
# VALUES03             13729
# VALUES05             12287
# StandardValue            9
# dtype: int64

# %%
df2 = df.rename(columns={'outputcode':'OutputCode','pollutant_code':'PollutantCode','outputname':'OutputName','data_time':'MonitorTime','RevisedzsStrength':'RzsStrength','flow':'cou','VALUES01':'S01','VALUES03':'S03','VALUES05':'S05'})

# %%
df2.to_csv('huodian2019_v4-2.csv', index=False)
