# %%
dir(__builtin__)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EnvironmentError',
#  'Exception',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
#  'PermissionError',
#  'ProcessLookupError',
#  'RecursionError',
# ...

# %%
import urllib
dir(urllib)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  'error',
#  'parse',
#  'request',
#  'response']

# %% [markdown]
# 'error',
#  'parse',
#  'request',
#  'response'
#  这四个在cmd里都未出现

# %%
 help(urllib.request.urlopen) #cmd里需要先import urllib.request，但不用先import urllib.request.urlopen
# Out:
# Help on function urlopen in module urllib.request:
#
# urlopen(url, data=None, timeout=<object object at 0x0000020CCE9AB770>, *, cafile=None, capath=None, cadefault=False, context=None)
#     Open the URL url, which can be either a string or a Request object.
#
#     *data* must be an object specifying additional data to be sent to
#     the server, or None if no such data is needed.  See Request for
#     details.
#
#     urllib.request module uses HTTP/1.1 and includes a "Connection:close"
#     header in its HTTP requests.
#
#     The optional *timeout* parameter specifies a timeout in seconds for
#     blocking operations like the connection attempt (if not specified, the
#     global default timeout setting will be used). This only works for HTTP,
#     HTTPS and FTP connections.
#
#     If *context* is specified, it must be a ssl.SSLContext instance describing
#     the various SSL options. See HTTPSConnection for more details.
#
# ...
